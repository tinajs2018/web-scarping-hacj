# %%
# Write a Python program to test if a given page is found or not on the server
import requests
from bs4 import BeautifulSoup
import urllib
# Out:
# /home/hp/anaconda3/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
url='https://invidgroup.com/what-is-data-insights-and-analytics/'
data=requests.get(url)
print(data)
print(data.status_code)
# Out:
# <Response [403]>
# 403

# %%
from urllib.request import urlopen

from urllib.error import *
# from urllib.error import *
try:
    url="https://invidgroup.com/what-is-data-insights-and-analytics/"
except  HTTPSError as a:
          print("http error",a)
except URLError as a:
         print('url error',a)
else:
    print('Found it')
# Out:
# Found it

# %%
#Write a Python program to download and display the content of robot.txt for en.wikipedia.org.
url2="https://en.wikipedia.org/robots.txt"
data=requests.get(url2)
print(data.text)
# Out:
# ﻿# robots.txt for http://www.wikipedia.org/ and friends
# #
# # Please note: There are a lot of pages on this site, and there are
# # some misbehaved spiders out there that go _way_ too fast. If you're
# # irresponsible, your access to the site may be blocked.
# #
#
# # Observed spamming large amounts of https://en.wikipedia.org/?curid=NNNNNN
# # and ignoring 429 ratelimit responses, claims to respect robots:
# # http://mj12bot.com/
# User-agent: MJ12bot
# Disallow: /
#
# # advertising-related bots:
# User-agent: Mediapartners-Google*
# Disallow: /
#
# # Wikipedia work bots:
# User-agent: IsraBot
# Disallow:
#
# User-agent: Orthogaffe
# Disallow:
#
# # Crawlers that are kind enough to obey, but which we'd rather not have
# # unless they're feeding search engines.
# User-agent: UbiCrawler
# Disallow: /
#
# User-agent: DOC
# Disallow: /
#
# User-agent: Zao
# Disallow: /
#
# # Some bots are known to be trouble, particularly those designed to copy
# ...

# %%
#Write a Python program to extract and display all the header tags from en.wikipedia.org/wiki/Main_Page.#
data=requests.get("https://en.wikipedia.org/wiki/Main_Page")
soup=BeautifulSoup(data.content,'html.parser')
for i in soup.find_all(['h1','h2','h3','h4','h5','h5']):
    print(i.name,i.get_text())
# Out:
# h1 Main Page
# h2 From today's featured article
# h2 Did you know ...
# h2 In the news
# h2 On this day
# h2 Today's featured picture
# h2 Other areas of Wikipedia
# h2 Wikipedia's sister projects
# h2 Wikipedia languages
# h2 Navigation menu
# h3
# Personal tools
#
# h3
# Namespaces
#
# h3
# Variants
# expanded
# collapsed
#
# h3
# Views
#
# h3
# More
# expanded
# collapsed
#
# h3
# Search
#
# h3
# Navigation
#
# h3
# Contribute
#
# h3
# Tools
#
# h3
# Print/export
#
# h3
# In other projects
#
# h3
# Languages

# %%
import numpy as np
check=np.fromstring('1 2 3 4 5',dtype=float,sep=' ')
print(check)
# Out:
# [1. 2. 3. 4. 5.]

# %%
# Write a Python program to extract and display all the image
#links from en.wikipedia.org/wiki/Peter_Jeffrey_(RAAF_officer)
from urllib.request import urlopen
import  re
from bs4 import BeautifulSoup
dev=urlopen('https://en.wikipedia.org/wiki/Peter_Jeffrey_(RAAF_officer)')
# dec=BeautifulSoup(dev,'html.parser')
dec = BeautifulSoup(dev, 'html.parser')
image=dec.find_all('img',{'scr':re.compile('.jpg')})
for image in images:
    print(image['src'] +'\n')
# Out:
# //upload.wikimedia.org/wikipedia/commons/thumb/a/af/NlaJeffrey1942-43.jpg/220px-NlaJeffrey1942-43.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/c/c5/008315JeffreyTurnbull1941.jpg/260px-008315JeffreyTurnbull1941.jpg
#
# //upload.wikimedia.org/wikipedia/commons/e/ea/021807CameronJeffrey1941.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/9/92/AC0072JeffreyTruscottKittyhawks1942.jpg/280px-AC0072JeffreyTruscottKittyhawks1942.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/2/26/VIC1689Jeffrey1945.jpg/280px-VIC1689Jeffrey1945.jpg

# %%
# Write a Python program to get 90 days of visits broken down by browser for all sites on data.gov.
import requests
data=requests.get('https://analytics.usa.gov/data/live/browsers.json')
print(data.json()['totals']['browser'])
# Out:
# {'Chrome': 2453491180, 'Safari': 1880428403, 'Edge': 327131741, 'Firefox': 144047966, 'Samsung Internet': 105294525, 'Internet Explorer': 50730654, 'Safari (in-app)': 76800019, 'Android Webview': 58060505, 'Opera': 16230645, 'Amazon Silk': 9144911, 'Mercari_d': 4990422, 'YaBrowser': 1890455, 'Mozilla Compatible Agent': 2679242, 'Welltory': 2513911, 'UC Browser': 1603289, 'Android Browser': 253270, 'TE_IEP': 1072157, 'Opera Mini': 724191, 'Coc Coc': 552491, 'bitdiscovery': 1687491, 'Sparkle': 356915, 'ELB-HealthChecker': 539393, 'ThousandEyes': 180783, 'SmartTraveler.iOS': 163986, 'Walgreens': 97989, 'M': 87867, 'SeaMonkey': 87744, 'Mozilla': 88900, 'Android Runtime': 57220, 'Puffin': 57584, 'IRS - TRG19-01Loeim': 62653, '(not set)': 35924, 'United States Postal Service - TRG19-01Loeim': 50063, 'mozilla': 26742, 'DoximityWebView': 33237, 'Carousel': 37461, 'candroid': 22417, '[FBAN': 38407, 'BestBuy': 92494, 'Iron': 26998, 'Microsoft Office Word 2014': 15010, 'Maxthon': 25280, 'HRB-MO
# ...

# %%
# Write a Python program to that retrieves an arbitary 
#Wikipedia page of "Python" and creates a list of links on that page
import requests
dep=urlopen('https://en.wikipedia.org/wiki/Python_(programming_language)')
soup=BeautifulSoup(dep,'html.parser')
d1=[]
for i in soup.find_all('a'):
    if 'href' in i.attrs:
        print(i.attrs['href'])
# Out:
# /wiki/Wikipedia:Good_articles
# #mw-head
# #searchInput
# /wiki/File:Python-logo-notext.svg
# /wiki/Programming_paradigm
# /wiki/Multi-paradigm_programming_language
# /wiki/Object-oriented_programming
# #cite_note-1
# /wiki/Procedural_programming
# /wiki/Imperative_programming
# /wiki/Functional_programming
# /wiki/Structured_programming
# /wiki/Reflective_programming
# /wiki/Software_design
# /wiki/Guido_van_Rossum
# /wiki/Software_developer
# /wiki/Python_Software_Foundation
# #cite_note-alt-sources-history-2
# /wiki/Software_release_life_cycle
# #cite_note-wikidata-48603703835a24cdee9c0f27c8f7fc9cd39f1d83-v3-3
# https://www.wikidata.org/wiki/Q28865?uselang=en#P348
# /wiki/Software_release_life_cycle#Beta
# #cite_note-wikidata-48603703835a24cdee9c0f27c8f7fc9cd39f1d83-v3-3
# https://www.wikidata.org/wiki/Q28865?uselang=en#P348
# /wiki/Type_system
# /wiki/Duck_typing
# /wiki/Dynamic_typing
# /wiki/Strong_and_weak_typing
# #cite_note-4
# /wiki/Gradual_typing
# /wiki/CPython
# ...

# %%
#Write a Python program to get the number of magnitude 4.5+ earthquakes detected worldwide by the USGS.
